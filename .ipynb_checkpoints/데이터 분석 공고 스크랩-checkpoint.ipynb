# %%
import numpy as np
import pandas as pd
import re
import selenium
import time

from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.common.by import By

# %%
# Open Chrome
driver = webdriver.Chrome('C:/Users/li016/chromedriver/chromedriver.exe')

# %%
def get_data_info(keyword):
    # "원티드" 접속 by keyword
    url = f"https://www.wanted.co.kr/search?query={keyword}"
    driver.get(url)
    driver.implicitly_wait(5)

    # 신입 카테고리 설정 
    # click "경력"
    #driver.find_element_by_css_selector("#__next > div.Search_className__7YET5 > div:nth-child(3) > div > div > div > div > div.FilterInWdlist_SelectedButtonGroup__3KRGs > button:nth-child(5)").click()
    # select "신입"
    #select = Select(driver.find_element_by_css_selector("#MODAL_BODY > div > div > select"))
    #select.select_by_index(1)
    # click "확인"
    #driver.find_element_by_css_selector("#__next > div.Search_className__7YET5 > div:nth-child(3) > div > div > div.Modal_root__1aywk > div.Modal_modalContent__X5ATV.YearsPopup_container__1ngcC > div > div.CommonFooter_container__qo8Wv > button").click()

    # 포지션 수 get
    position = driver.find_element_by_css_selector("#__next > div.Search_className__7YET5 > div:nth-child(3) > h2").text
    pos_num = re.findall("[1-9]+",position)[0]
    pos_num = int(pos_num)
    
    info_list = []
    # 범위 설정
    for i in range(1, pos_num + 1):
        # 직무명 & 회사명 get
        job_info = driver.find_element_by_css_selector(
          f'#__next > div.Search_className__7YET5 > div:nth-child(3) > div > div > ul > li:nth-child({i}) > div > a > div'
        ).text
        job_info = job_info.split('\n')
        job_name = job_info[0]
        company_name = job_info[1]

        # 특정 채용 공고로 이동
        driver.find_element_by_css_selector(f'#__next > div.Search_className__7YET5 > div:nth-child(3) > div > div > ul > li:nth-child({i}) > div > a').click()
        driver.implicitly_wait(10)

        # 채용 공고 text 전체 get
        table_text = driver.find_element_by_class_name('JobDescription_JobDescription__3vTNT').text
        table_text = table_text.replace("\n", '').replace('[주요업무]', '')

        # 주요업무, 자격요건, 우대사항 get
        try:
            main_task = table_text.split("주요업무")[1].split("자격요건")[0]
            qualification = table_text.split("주요업무")[1].split("자격요건")[1].split("우대사항")[0]
            prefer_treat = table_text.split("주요업무")[1].split("자격요건")[1].split("우대사항")[1].split('혜택')[0]

            info_list.append([company_name, job_name, main_task, qualification, prefer_treat])
        except:
            info_list.append([company_name, job_name, np.nan, np.nan, np.nan])

        driver.back()
    result_df = pd.DataFrame(data=info_list, columns=['회사명', '직무명', '주요업무', '자격요건', '우대사항'])
    return result_df

# %%
keyword_list = ["데이터 분석가", "data analyst"]
data_post_df = pd.DataFrame()

for keyword in keyword_list:
    data_post_df = pd.concat([data_post_df, get_data_info(keyword)], axis=0)

# %%
# 경력직 X
my_data_post_df = data_post_df[(data_post_df['직무명'].str.contains("년") == False) &
                              (data_post_df['자격요건'].str.contains("년 이상") == False) &
                              (data_post_df['자격요건'].str.contains("년이상") == False)]
my_data_post_df = my_data_post_df.reset_index(drop=True)

# %%
# 내가 보기 편하게 디자인
my_data_post_df
# Out:
#                    회사명                                                직무명  \
# 0            콜로세움코퍼레이션                             데이터 분석가 (Data Analyst)
# 1        딜라이트룸(Alarmy)                                            데이터 분석가
# 2                  그로비                                 데이터 분석가 (주니어~시니어급)
# 3        플라이셔(Flysher)                                  게임 데이터 분석가 (신입가능)
# 4            크몽(kmong)                                            데이터 분석가
# 5               마이리얼트립                                            데이터 분석가
# 6            인플루엔셜(윌라)                                       [윌라] 데이터 분석가
# 7                  빅밸류                                   데이터 분석가 (감염, 검역)
# 8    매스프레소(Mathpresso)                             Data Analyst (데이터 분석가)
# 9                 당근마켓                                       프로덕트 데이터 분석가
# 10         콘센트릭스서비스코리아                             데이터 분석가 (사원~부장급 총 10명)
# 11                  대교                                            데이터 분석가
# 12            나이스지니데이타                                           빅데이터 분석가
# 13        넥슨코리아(NEXON)                         [인텔리전스랩스] 데이터 분석가 (개인화메시징)
# 14  데브시스터즈(Devsisters)                              [쿠키런: 오븐브레이크] 데이터 분석가
# 15                토니모리                                            데이터 분석가
# 16            마이티하이브한국  Digital Analytics Specialist, Data Analytics(데...
# 17          모션투에이아이코리아                              Customer Data Analyst
# 18           콜로세움코퍼레이션                             데이터 분석가 (Data Analyst)
# 19       딜라이트룸(Alarmy)                     Data Analyst (Product Analyst)
# 20               베스텔라랩  빅데이터 개발자(DATA Analyst/DATA Scentis/DATA Engineer)
# 21              토스페이먼츠                                       Data Analyst
# 22      밸런스히어로 (트루밸런스)                              Data Analyst (Junior)
# 23         비바리퍼블리카(토스)                                  [토스] Data Analyst
# 24         비바리퍼블리카(토스)                                [토스증권] Data Analyst
# 25          에이모(AIMMO)                                       Data Analyst
# 26        29CM(에이플러스비)                                       Data Analyst
# 27            프렌트립(프립)                                  DA (Data Analyst)
# 28   매스프레소(Mathpresso)                             Data Analyst (데이터 분석가)
# 29                하나투어                               CRM기획 - DATA ANALYST
# 30  코드스테이츠(CodeStates)                            Data Analyst (Outcomes)
# 31         브랜디(Brandi)                                  [랩스] Data Analyst
#
#                                                  주요업무  \
# 0   - 콜로세움 서비스 관련 정량적/정성적 데이터 관리 및 분석- 데이터 기반의 비즈니...
# 1   • 전사에서 진행되는 각종 실험(e.g., A/B 테스팅) 결과 리뷰와 분석• 데이...
# 2   • 경쟁사 분석 및 B2B 마케팅 데이터를 활용한 전략 수립 및 실행• 서비스 데이...
# 3   • 로그 설계 : 게임을 플레이하며 의사결정에 필요할 정보를 DB에 어떻게 쌓을지 ...
# 4   • 데이터 기반 의사결정을 위한 데이터 분석 기획 및 실행• 데이터 분석 결과를 시...
# 5   - 서비스 핵심지표 정의 및 관리- 데이터 분석을 위한 환경 구축 및 개선 (데이터...
# 6   • 데이터 분석 실무       - 분석 도구를 활용한 대용량 RAW 데이터 분석 ...
# 7   ㆍ인간, 동물 감염병 관련 프로젝트 추진ㆍ감염병 확산 알고리즘 및 솔루션 리드ㆍ공공...
# 8   • 서비스 지표 상승 및 문제 해결을 위한 데이터 기반의 인사이트 제공• 데이터 분...
# 9   • 팀 전체가 데이터 중심의 의사결정을 내릴 수 있도록 주도적으로 일해요• 프로덕트...
# 10  - BigQuery를 활용한 GA(Google Analytics) 데이터 분석- B...
# 11  • 태블로(Tableau) 및 타 BI솔루션을 활용한 대시보드 기획 및 개발• 데이...
# 12  • 정형/비정형 데이터분석• 내외부 빅데이터를 활용한 모델개발• 시장 트렌드 분석/...
# 13  ＜어떤 일을 하나요?＞오늘 아침 9시에 받은 그 앱 푸시는, 당신이 앱을 실행하게 ...
# 14  - 데이터웨어하우스 구축: 로그를 가공하여 분석에 필요한 데이터웨어하우스를 설계 및...
# 15  • 매장/이커머스 판매 및 고객 데이터, SAP 내 재고 및 손익 등에 대한 맞춤형...
# 16  • 데이터 컨설턴트로서 고객의 디지털 프로젝트를 관리하고, 결과를 만들어내는 역할•...
# 17  • 실시간 센서 데이터 및 고객사 데이터 수집• 효율성 및  안전관련 엔지니어링 •...
# 18  - 콜로세움 서비스 관련 정량적/정성적 데이터 관리 및 분석- 데이터 기반의 비즈니...
# 19  • 전사에서 진행되는 각종 실험(e.g., A/B 테스팅) 결과 리뷰와 분석• 데이...
# 20  - 자사 서비스에서 수집된 주차정보 빅데이터 플랫폼 구축 업무 - * DATA An...
# 21  • 토스 앱 및 토스페이먼츠의 웹, 그리고 거래 레벨에서 발생하는 Raw Data들...
# 22  - True Balance의 다양한 Mobile 서비스에 대한 Product/Fea...
# 23  • 각 서비스 사일로 및 토스 전체가 Data-driven 의사결정을 내릴 수 있도...
# 24  • 각 서비스 사일로 및 토스증권 전체가 Data-driven 의사결정을 내릴 수 ...
# 25  - 프로젝트 일정 및 범위 협의를 위한 기술지원- 프로젝트 진행 효율화 및 상태점검...
# 26  • 비즈니스/제품에 대한 Data-driven 의사결정을 내릴 수 있도록 정량적 수...
# 27  • Growth 조직 운영에 따라 스쿼드로 배정하여 업무를 진행- Frip Acqu...
# 28  • 서비스 지표 상승 및 문제 해결을 위한 데이터 기반의 인사이트 제공• 데이터 분...
# 29                          • Business & Data Analyst
# 30  [포지션 소개]코드스테이츠의 교육 프로그램을 통해 수백명의 구직을 원하는 수강생들이...
# 31  1. Data Driven Product DA• Product/Feature 단위 ...
#
#                                                  자격요건  \
# 0   ■ 공통 역량-책임감과 약속을 중요하게 여기며, 소속/타팀원과의 신뢰를 잘 쌓으실 ...
# 1   • Data Analyst, Data Consulting, Data Engineer...
# 2   • 경력 : 데이터 분석 경험 (신입 또는 경력(1~2년 미만))• 데이터 분석을 ...
# 3   • SQL(Redshift)에 능숙한 분• 통계 지식 및 데이터 분석에 필요한 하나...
# 4   • SQL을 활용한 데이터 추출 업무 경험• 정형 및 비정형 데이터를 Numpy, ...
# 5   - SQL, Python, R 등을 이용한 데이터 추출 및 가공 능력- 기본적인 통...
# 6   • SQL 활용 가능자 , 엑셀 중급 이상• 데이터 분석 도구, BI 도구 활용 스...
# 7   ㆍ공간데이터, GIS 등 관련 석사 이상 졸업 or 의료, 수의학 관련 석사 이상 ...
# 8   • 단순한 아이디어 차원이 아닌 실질적인 action을 위한 구체적인 인사이트를 제...
# 9   • A/B 테스트를 설계하고 결과를 분석하고 프로덕트에 기능을 적용한 경험이 풍부하...
# 10  - AWS, Azure, GCP 등 클라우드 플랫폼 관련 경험자- 쿼리문을 활용하여...
# 11  • Tableau 등 시각화 툴을 활용한 대시보드 설계 및 운영 경험• SQL을 활...
# 12  • 대졸이상(4년)으로 해당업무 경험자• 채용형태: 계약직 1년 (이후 정규직 전환...
# 13  • 논리적, 분석적 사고력 • 실험 설계, 통계학 지식 • Python, SQL, ...
# 14  - Game Enthusiastic: 게임을 좋아하시는 분 (모바일 게임 뿐만 아니...
# 15  • 경력 : 1~7년• 통계지식에 대한 이해와 문제해결능력• 빅데이터를 활용한 상품...
# 16  • 신입 또는  5년 이하의 디지털 마케팅 분야 실무팀/Agency/Consulta...
# 17  • Python (pandas, numpy), R, SQL, and/or VBA 사...
# 18  ■ 공통 역량-책임감과 약속을 중요하게 여기며, 소속/타팀원과의 신뢰를 잘 쌓으실 ...
# 19  • Data Analyst, Data Consulting, Data Engineer...
# 20  - Pyton, SAS, R, SQL 등 프로그램 가능자- 컴퓨터 및 수학, 통계 ...
# 21  • SQL을 사용한 Raw Data 핸들링 역량이 필요합니다.• Raw Data의 ...
# 22  - 숙련된 SQL Skill을 보유하신 분- 다양한 모바일 데이터 분석 방법에 대한...
# 23  • 모바일 서비스 데이터 분석 방법(LTV, AARRR, Cohort, Funnel...
# 24  • 모바일 서비스 데이터 분석 방법(LTV, AARRR, Cohort, Funnel...
# 25  - 꼼꼼하고 세심한 업무성향- 기술이슈 대응능력 및 일반인 대상 기술설명이 가능한 ...
# 26  • SQL을 사용한 Raw Data 기본 분석이 가능하신 분• 복잡하고 다양한 데이...
# 27  • 자신만의 가설을 통하여, 검증하고 결과물을 만들 낸 경험이 있으신 분 → 해당 ...
# 28  • 단순한 아이디어 차원이 아닌 실질적인 action을 위한 구체적인 인사이트를 제...
# 29  • (필수) SQL,Python을 이용한 빅데이터 분석 경험자• (필수) 분석업무 ...
# 30  •코드스테이츠 교육 및 채용 서비스와 그 데이터에 관심있는 분•데이터를 통해 통계적...
# 31  • A/B 테스트가 올바르게 설계되고 측정되도록 가이드하며 실험 결과를 deep-d...
#
#                                                  우대사항
# 0   -3년이상 데이터 분석 및 지표 관리 관련 직무 경력-통계학/산업공학 등 데이터 분...
# 1   • 분석을 위한 프로그래밍 역량이 있으신 분 (e.g., 스크립트를 통한 자동화, ...
# 2   • 데이터 분석 관련 직무 유 경험자 (관련 업무 2~3년)• 데이터 시각화 프로그...
# 3   • 직무 관련 전공자 (컴퓨터공학/통계/수학 등)• Cloud(AWS 등) 개발 환...
# 4   • 이커머스, 프리랜서, HR 도메인의 데이터 분석 경험이 있는 분 • Google...
# 5   - Appsflyer, Adjust 등의 어트리뷰션 툴을 사용한 경험이 있는 분- ...
# 6   • 데이터 분석, 통계 관련 전공자• 콘텐츠 구독서비스, 이커머스 분야 등 대용량 ...
# 7                     ㆍ공간 데이터 분석 경험ㆍ질병, 방역 관련 프로젝트 경험
# 8   • Growth팀(Growth Hacking) 또는 Lean Startup에 대한 ...
# 9   • 3년 이상 프로덕트 팀에서 서비스 분석을 해보신 분• 데이터 분석 결과를 가지고...
# 10  - GCP 및 BigQuery 관련 경력 1년 이상인 분- BigQuery를 활용한...
# 11  • 데이터를 활용한 원활한 의사소통과 데이터 기반의 사고 방법을 전사적으로 공유할 ...
# 12  • 데이터분석 관련학과 및 전산학과 출신 (수학/통계학, 경영학, 산업공학,전산학 ...
# 13  • 다양한 장르의 게임을 깊이 있게 즐긴 경험 (게임 캐릭터의 성장 / 게임 경제 ...
# 14  - 3년 이상의 데이터 분석 실무 경력 (업계 무관)- Pandas, Numpy, ...
# 15  • 빅데이터 인프라 경험자 우대• 화장품 등 유통 산업 경험자 우대• 외국어 능력 ...
# 16  • 유창한 영어 소통 능력 (영어 면접 진행)• Google Tag Manager,...
# 17  • 비지니스 모델 발굴 경험• B2B 고객사 대응 업무 경험 및 고객사 중심 Q/A...
# 18  -3년이상 데이터 분석 및 지표 관리 관련 직무 경력-통계학/산업공학 등 데이터 분...
# 19  • 분석을 위한 프로그래밍 역량이 있으신 분 (e.g., 스크립트를 통한 자동화, ...
# 20    - 자율주행 및 빅테이터 플랫폼 구축 유경험자- 관련 학과 석/박사 및 자격증 소유자
# 21  • 웹 및 모바일 서비스 데이터 분석 방법(AARRR, Cohort 등)에 대한 높...
# 22  - 데이터 분석 경력 3년 이상이신 분- 금융 서비스에 대한 데이터 분석 경험이 있...
# 23  • Python, R, Spark 등을 활용한 데이터 프로세싱에 대한 이해도가 높으...
# 24  • Python, R, Spark 등을 활용한 데이터 프로세싱에 대한 이해도가 높으...
# 25  - 반복적인 업무 자동화가 가능한 수준의 Python 활용능력- OpenCV, Py...
# 26  • 통계, 수학, 컴퓨터공학 전공자 우대• Tableau, Power BI 등 BI...
# 27  • GA, Firebase, Amplitude를 이용하여 제품 분석을 진행한 경험•...
# 28  • Growth팀(Growth Hacking) 또는 Lean Startup에 대한 ...
# 29  • 빅데이터 분석과 알고리즘 모델링 개발 경험자(우대)• 능숙한 SQL 활용역량 보...
# 30  •데이터 수집, 전처리, 분석, 결과 공유 등의 전체적인 프로세스를 경험한 분•대시...
# 31  • 내부 데이터 엔지니어들과 원활하게 소통하며 프로젝트를 진행해보신 분• 데이터 분...
